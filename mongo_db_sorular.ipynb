# %%
from pymongo import MongoClient

# %%
SEED_DATA = [
  {
    'genre': 'Fantasy',
    'title': 'The Lord of the Rings: The Fellowship of the Ring',
    'author': 'J.R.R. Tolkien',
    'year': 1954,
  },
  {
    'genre': 'Science Fiction',
    'title': 'Dune',
    'author': 'Frank Herbert',
    'year': 1965,
  },
  {
    'genre': 'Dystopian',
    'title': '1984',
    'author': 'George Orwell',
    'year': 1949,
  }
]

# %% [markdown]
# UYGULAMALAR

# %% [markdown]
# mongo db'den yeni bir veri tabanı ve collection oluşturup buna bağlanın

# %%
connection_string="mongodb+srv://zeynepcolakbozkurt:4791613Ev.@deneme1.86go0.mongodb.net/"

# %%
client=MongoClient(connection_string)
client
# Out:
# MongoClient(host=['deneme1-shard-00-01.86go0.mongodb.net:27017', 'deneme1-shard-00-02.86go0.mongodb.net:27017', 'deneme1-shard-00-00.86go0.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-5op4ug-shard-0', tls=True)

# %%
db=client['zeynep']
collection=db['books']

# %%
import random
new_data=[]
for i in range(100):
    veriler=random.choice(SEED_DATA)
    yeni_veri={
        'tür':veriler['genre'],
        'başlık':veriler['title'],
        'yazar':veriler['author'],
        'yıl':veriler['year']
    }
    new_data.append(yeni_veri)
for veri in new_data:
    print(veri)
# Out:
# {'tür': 'Fantasy', 'başlık': 'The Lord of the Rings: The Fellowship of the Ring', 'yazar': 'J.R.R. Tolkien', 'yıl': 1954}
# {'tür': 'Science Fiction', 'başlık': 'Dune', 'yazar': 'Frank Herbert', 'yıl': 1965}
# {'tür': 'Fantasy', 'başlık': 'The Lord of the Rings: The Fellowship of the Ring', 'yazar': 'J.R.R. Tolkien', 'yıl': 1954}
# {'tür': 'Dystopian', 'başlık': '1984', 'yazar': 'George Orwell', 'yıl': 1949}
# {'tür': 'Dystopian', 'başlık': '1984', 'yazar': 'George Orwell', 'yıl': 1949}
# {'tür': 'Science Fiction', 'başlık': 'Dune', 'yazar': 'Frank Herbert', 'yıl': 1965}
# {'tür': 'Science Fiction', 'başlık': 'Dune', 'yazar': 'Frank Herbert', 'yıl': 1965}
# {'tür': 'Dystopian', 'başlık': '1984', 'yazar': 'George Orwell', 'yıl': 1949}
# {'tür': 'Dystopian', 'başlık': '1984', 'yazar': 'George Orwell', 'yıl': 1949}
# {'tür': 'Fantasy', 'başlık': 'The Lord of the Rings: The Fellowship of the Ring', 'yazar': 'J.R.R. Tolkien', 'yıl': 1954}
# ...

# %%
collection.insert_many(new_data)
# Out:
# InsertManyResult([ObjectId('675da0d55575bd814faa36e7'), ObjectId('675da0d55575bd814faa36e8'), ObjectId('675da0d55575bd814faa36e9'), ObjectId('675da0d55575bd814faa36ea'), ObjectId('675da0d55575bd814faa36eb'), ObjectId('675da0d55575bd814faa36ec'), ObjectId('675da0d55575bd814faa36ed'), ObjectId('675da0d55575bd814faa36ee'), ObjectId('675da0d55575bd814faa36ef'), ObjectId('675da0d55575bd814faa36f0'), ObjectId('675da0d55575bd814faa36f1'), ObjectId('675da0d55575bd814faa36f2'), ObjectId('675da0d55575bd814faa36f3'), ObjectId('675da0d55575bd814faa36f4'), ObjectId('675da0d55575bd814faa36f5'), ObjectId('675da0d55575bd814faa36f6'), ObjectId('675da0d55575bd814faa36f7'), ObjectId('675da0d55575bd814faa36f8'), ObjectId('675da0d55575bd814faa36f9'), ObjectId('675da0d55575bd814faa36fa'), ObjectId('675da0d55575bd814faa36fb'), ObjectId('675da0d55575bd814faa36fc'), ObjectId('675da0d55575bd814faa36fd'), ObjectId('675da0d55575bd814faa36fe'), ObjectId('675da0d55575bd814faa36ff'), ObjectId('675da0d55575bd814faa
# ...

# %% [markdown]
# soru2: kendiniz yukarıdakine benzer ama sadece 1 doküman oluşturup bu dokümanı mongodb ye aktarınız. bunun için insert_many() methodunu kullanmayınız.

# %%
veri= {
  
    'tür': 'Fantasy',
    'başlık': 'Harry Potter',
    'yazar': 'J.K Rowling',
    'yıl': 1997,
  }

collection.insert_one(veri)
# Out:
# InsertOneResult(ObjectId('675da0d65575bd814faa374b'), acknowledged=True)

# %%
veriler=collection.find({'yazar':'J.K Rowling'})
for veri in veriler:
    print(veri)
# Out:
# {'_id': ObjectId('675d98745575bd814faa367d'), 'tür': 'Fantasy', 'başlık': 'Harry Potter', 'yazar': 'J.K Rowling', 'yıl': 1997}
# {'_id': ObjectId('675d9a455575bd814faa367e'), 'tür': 'Fantasy', 'başlık': 'Harry Potter', 'yazar': 'J.K Rowling', 'yıl': 1997}
# {'_id': ObjectId('675d9b135575bd814faa36e4'), 'tür': 'Fantasy', 'başlık': 'Harry Potter', 'yazar': 'J.K Rowling', 'yıl': 1997}
# {'_id': ObjectId('675da07f5575bd814faa36e5'), 'tür': 'Fantasy', 'başlık': 'Harry Potter', 'yazar': 'J.K Rowling', 'yıl': 1997}
# {'_id': ObjectId('675da0d65575bd814faa374b'), 'tür': 'Fantasy', 'başlık': 'Harry Potter', 'yazar': 'J.K Rowling', 'yıl': 1997}

# %% [markdown]
# soru3: author fieldı George Orwell olan documentin genre Fieldını Science_Fiction olarak güncelleyiniz ve yazdırınız

# %%
sorgu={'yazar':'George Orwell'}
collection.update_many(sorgu,{'$set':{'tür':'Science_Fiction'}})
# Out:
# UpdateResult({'n': 191, 'electionId': ObjectId('7fffffff000000000000000a'), 'opTime': {'ts': Timestamp(1734189270, 40), 't': 10}, 'nModified': 38, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1734189270, 40), 'signature': {'hash': b'\xc6\x1f\x16]\xef\xd3\xd9L(\xc6\xb1\x9cRk\xa8p\xefOWZ', 'keyId': 7418578331844476932}}, 'operationTime': Timestamp(1734189270, 40), 'updatedExisting': True}, acknowledged=True)

# %%
collection.delete_many({'tür':'Dystopian'})
# Out:
# DeleteResult({'n': 0, 'electionId': ObjectId('7fffffff000000000000000a'), 'opTime': {'ts': Timestamp(1734189270, 40), 't': 10}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1734189270, 40), 'signature': {'hash': b'\xc6\x1f\x16]\xef\xd3\xd9L(\xc6\xb1\x9cRk\xa8p\xefOWZ', 'keyId': 7418578331844476932}}, 'operationTime': Timestamp(1734189270, 40)}, acknowledged=True)

# %%
veri=collection.find(sorgu)
for data in veri:
    print(data)
# Out:
# {'_id': ObjectId('675d91ff0d87770222693b88'), 'tür': 'Science_Fiction', 'başlık': '1984', 'yazar': 'George Orwell', 'yıl': 1949, 'genre': 'Science_Fiction'}
# {'_id': ObjectId('675d91ff0d87770222693b8b'), 'tür': 'Science_Fiction', 'başlık': '1984', 'yazar': 'George Orwell', 'yıl': 1949, 'genre': 'Science_Fiction'}
# {'_id': ObjectId('675d91ff0d87770222693b8d'), 'tür': 'Science_Fiction', 'başlık': '1984', 'yazar': 'George Orwell', 'yıl': 1949, 'genre': 'Science_Fiction'}
# {'_id': ObjectId('675d91ff0d87770222693b8e'), 'tür': 'Science_Fiction', 'başlık': '1984', 'yazar': 'George Orwell', 'yıl': 1949, 'genre': 'Science_Fiction'}
# {'_id': ObjectId('675d91ff0d87770222693b93'), 'tür': 'Science_Fiction', 'başlık': '1984', 'yazar': 'George Orwell', 'yıl': 1949, 'genre': 'Science_Fiction'}
# {'_id': ObjectId('675d91ff0d87770222693b97'), 'tür': 'Science_Fiction', 'başlık': '1984', 'yazar': 'George Orwell', 'yıl': 1949, 'genre': 'Science_Fiction'}
# ...

# %% [markdown]
# soru4: kitabın basım yılının 1950 den fazla olanlarını yazdır. for döngüsü ile anlaşılabilir bir format oluştur. bunun için'$gte' methodunu kullan

# %%
veriler=collection.find({'yıl':{'$gte':1950}})
for veri in veriler:
    print(f"""
        ------------------------------
        Kitap Türü:{veri['tür']}
        Kitap Adı:{veri['başlık']}
        Kitap Yazarı:{veri['yazar']}
        Kitap Yılı:{veri['yıl']}
        ------------------------------

""")
# Out:
#         ------------------------------
#         Kitap Türü:Science Fiction
#         Kitap Adı:Dune
#         Kitap Yazarı:Frank Herbert
#         Kitap Yılı:1965
#         ------------------------------
#
#
#
#         ------------------------------
#         Kitap Türü:Science Fiction
#         Kitap Adı:Dune
#         Kitap Yazarı:Frank Herbert
#         Kitap Yılı:1965
#         ------------------------------
#
#
#
#         ------------------------------
#         Kitap Türü:Fantasy
#         Kitap Adı:The Lord of the Rings: The Fellowship of the Ring
#         Kitap Yazarı:J.R.R. Tolkien
#         Kitap Yılı:1954
#         ------------------------------
#
#
#
#         ------------------------------
#         Kitap Türü:Science Fiction
#         Kitap Adı:Dune
#         Kitap Yazarı:Frank Herbert
#         Kitap Yılı:1965
#         ------------------------------
#
#
#
#         ------------------------------
#         Kitap Türü:Fantasy
# ...
